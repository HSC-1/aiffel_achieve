# %%
import re
import six
import math
import lmdb
import os
import numpy as np
import tensorflow as tf

from PIL import Image

from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras.utils import Sequence
from tensorflow.keras import backend as K
from tensorflow.keras.models import load_model

BATCH_SIZE = 128
HOME_DIR = os.getenv('HOME')+'/aiffel/ocr'

# 로컬 사용자
TRAIN_DATA_PATH = HOME_DIR+'/MJ/MJ_train'
VALID_DATA_PATH = HOME_DIR+'/MJ/MJ_valid'
TEST_DATA_PATH = HOME_DIR+'/MJ/MJ_test'

print(TRAIN_DATA_PATH)
# Out:
# /home/aiffel-dj26/aiffel/ocr/MJ/MJ_train

# %%
NUMBERS = "0123456789"
ENG_CHAR_UPPER = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
TARGET_CHARACTERS = ENG_CHAR_UPPER + NUMBERS
print(f"The total number of characters is {len(TARGET_CHARACTERS)}")
# Out:
# The total number of characters is 36

# %%
from IPython.display import display

env = lmdb.open(TRAIN_DATA_PATH, max_readers=32, readonly=True, lock=False, readahead=False, meminit=False)
with env.begin(write=False) as txn:
    for index in range(1, 5):
        label_key = 'label-%09d'.encode() % index
        label = txn.get(label_key).decode('utf-8')
        img_key = 'image-%09d'.encode() % index
        imgbuf = txn.get(img_key)
        buf = six.BytesIO()
        buf.write(imgbuf)
        buf.seek(0)
        try:
            img = Image.open(buf).convert('RGB')

        except IOError:
            img = Image.new('RGB', (100, 32))
            label = '-'
        width, height = img.size
        print('original image width:{}, height:{}'.format(width, height))
        
        target_width = min(int(width*32/height), 100)
        target_img_size = (target_width,32 )
        
        print('target_img_size:{}'.format(target_img_size))
        
        img = np.array(img.resize(target_img_size)).transpose(1,0,2)
       
        print('display img shape:{}'.format(img.shape))
        print('label:{}'.format(label))
        display(Image.fromarray(img.transpose(1,0,2).astype(np.uint8)))
# Out:
# original image width:72, height:31
# target_img_size:(74, 32)
# display img shape:(74, 32, 3)
# label:Lube
# <PIL.Image.Image image mode=RGB size=74x32 at 0x7FD85812D850>
# original image width:82, height:31
# target_img_size:(84, 32)
# display img shape:(84, 32, 3)
# label:Spencerian
# <PIL.Image.Image image mode=RGB size=84x32 at 0x7FD858108290>
# original image width:115, height:31
# target_img_size:(100, 32)
# display img shape:(100, 32, 3)
# label:accommodatingly
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7FD85812D650>
# original image width:140, height:31
# target_img_size:(100, 32)
# display img shape:(100, 32, 3)
# label:CARPENTER
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7FD85812D910>

# %%
class MJDatasetSequence(Sequence):
    def __init__(self, 
                      dataset_path,
                      label_converter,
                      batch_size=1,
                      img_size=(100,32),
                      max_text_len=22,
                      is_train=False,
                      character=''
                ):
        
        self.label_converter = label_converter
        self.batch_size = batch_size
        self.img_size = img_size
        self.max_text_len = max_text_len
        self.character = character
        self.is_train = is_train
        self.divide_length = 100

        self.env = lmdb.open(dataset_path, max_readers=32, readonly=True, lock=False, readahead=False, meminit=False)
        with self.env.begin(write=False) as txn:
            num_samples = int(txn.get('num-samples'.encode()))
            self.num_samples = int(num_samples)
            self.index_list = [index + 1 for index in range(self.num_samples)]
        
    def __len__(self):
        if self.is_train:
            return math.ceil(self.num_samples/self.batch_size/self.divide_length)
        return math.ceil(self.num_samples/self.batch_size/self.divide_length)
    
    # index에 해당하는 image와 label을 가져오는 메소드
    def _get_img_label(self, index):
        with self.env.begin(write=False) as txn:
            label_key = 'label-%09d'.encode() % index
            label = txn.get(label_key).decode('utf-8')
            img_key = 'image-%09d'.encode() % index
            imgbuf = txn.get(img_key)

            buf = six.BytesIO()
            buf.write(imgbuf)
            buf.seek(0)
            try:
                img = Image.open(buf).convert('RGB')

            except IOError:
                img = Image.new('RGB', self.img_size)
                label = '-'
            width, height = img.size
            
            target_width = min(int(width*self.img_size[1]/height), self.img_size[0])
            target_img_size = (target_width,self.img_size[1] )
            img = np.array(img.resize(target_img_size)).transpose(1,0,2)
            label = label.upper()[:self.max_text_len]
            out_of_char = f'[^{self.character}]'
            label = re.sub(out_of_char, '', label)

        return (img, label)
    
    # idx번째 배치를 가져오는 메소드
    def __getitem__(self, idx):
        batch_indicies = self.index_list[
            idx*self.batch_size:
            (idx+1)*self.batch_size
        ]
        input_images = np.zeros([self.batch_size, *self.img_size, 3])
        labels = np.zeros([self.batch_size, self.max_text_len], dtype='int64')

        input_length = np.ones([self.batch_size], dtype='int64')*self.max_text_len
        label_length = np.ones([self.batch_size], dtype='int64')

        for i, index in enumerate(batch_indicies):
            img, label = self._get_img_label(index)
            encoded_label = self.label_converter.encode(label)
            width = img.shape[0]
            input_images[i,:width,:,:] = img
            if len(encoded_label) > self.max_text_len:
                continue
            labels[i,0:len(encoded_label)] = encoded_label
            label_length[i] = len(encoded_label)

        inputs = {
            'input_image': input_images,
            'label': labels,
            'input_length': input_length,
            'label_length': label_length,
        }
        outputs = {'ctc': np.zeros([self.batch_size, 1])}
        return inputs, outputs
        
    def on_epoch_end(self):
        self.index_list =  [index + 1 for index in range(self.num_samples)]
        if self.is_train :
            np.random.shuffle(self.index_list)
            return self.index_list

# %%
class LabelConverter(object):
     """ Convert between text-label and text-index """

     def __init__(self, character):
         self.character = "-" + character
         self.label_map = dict()
         for i, char in enumerate(self.character):
             self.label_map[char] = i

     def encode(self, text):
         encoded_label = []
         for i, char in enumerate(text):
             if i > 0 and char == text[i - 1]:
                 encoded_label.append(0)    # 같은 문자 사이에 공백 문자 label을 삽입
             encoded_label.append(self.label_map[char])
         return np.array(encoded_label)

     def decode(self, encoded_label):
         target_characters = list(self.character)
         decoded_label = ""
         for encode in encoded_label:
             decoded_label += self.character[encode]
         return decoded_label

# %%
label_converter = LabelConverter(TARGET_CHARACTERS)

encdoded_text = label_converter.encode('HELLO')
print("Encdoded_text: ", encdoded_text)
decoded_text = label_converter.decode(encdoded_text)
print("Decoded_text: ", decoded_text)
# Out:
# Encdoded_text:  [ 8  5 12  0 12 15]
# Decoded_text:  HEL-LO

# %%
def ctc_lambda_func(args): # CTC loss를 계산하기 위한 Lambda 함수
    labels, y_pred, label_length, input_length = args
    y_pred = y_pred[:, 2:, :]
    return K.ctc_batch_cost(labels, y_pred, input_length, label_length)

# %%
def build_crnn_model(input_shape=(100,32,3), characters=TARGET_CHARACTERS):
    num_chars = len(characters)+2
    image_input = layers.Input(shape=input_shape, dtype='float32', name='input_image')

    # Build CRNN model
    conv = layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(image_input)
    conv = layers.MaxPooling2D(pool_size=(2, 2))(conv)
    conv = layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(2, 2))(conv)
    conv = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.MaxPooling2D(pool_size=(1, 2))(conv)
    conv = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.BatchNormalization()(conv)
    conv = layers.Conv2D(512, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal')(conv)
    conv = layers.BatchNormalization()(conv)
    conv = layers.MaxPooling2D(pool_size=(1, 2))(conv)     
    feature = layers.Conv2D(512, (2, 2), activation='relu', kernel_initializer='he_normal')(conv)
    sequnce = layers.Reshape(target_shape=(24, 512))(feature)
    sequnce = layers.Dense(64, activation='relu')(sequnce)
    sequnce = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(sequnce)
    sequnce = layers.Bidirectional(layers.LSTM(256, return_sequences=True))(sequnce)
    y_pred = layers.Dense(num_chars, activation='softmax', name='output')(sequnce)

    labels = layers.Input(shape=[22], dtype='int64', name='label')
    input_length = layers.Input(shape=[1], dtype='int64', name='input_length')
    label_length = layers.Input(shape=[1], dtype='int64', name='label_length')
    loss_out = layers.Lambda(ctc_lambda_func, output_shape=(1,), name="ctc")(
        [labels, y_pred, label_length, input_length]
    )
    model_input = [image_input, labels, input_length, label_length]
    model = Model(
        inputs=model_input,
        outputs=loss_out
    )
    y_func = tf.keras.backend.function(image_input, [y_pred])
    return model, y_func

# %%
checkpoint_path = HOME_DIR + '/model_checkpoint.hdf5'

# %%
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 100, 32, 3)] 0
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 100, 32, 64)  1792        input_image[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 50, 16, 64)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 50, 16, 128)  73856       max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 25, 8, 128)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 25, 8, 256)   295168      max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 25, 8, 256)   590080      conv2d_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 25, 4, 256)   0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 25, 4, 512)   1180160     max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 25, 4, 512)   2048        conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 25, 4, 512)   2359808     batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 25, 4, 512)   2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_19 (MaxPooling2D) (None, 25, 2, 512)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 24, 1, 512)   1049088     max_pooling2d_19[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 24, 512)      0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 24, 64)       32832       reshape_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 24, 512)      657408      dense_4[0][0]
# __________________________________________________________________________________________________
# bidirectional_9 (Bidirectional) (None, 24, 512)      1574912     bidirectional_8[0][0]
# __________________________________________________________________________________________________
# label (InputLayer)              [(None, 22)]         0
# __________________________________________________________________________________________________
# output (Dense)                  (None, 24, 38)       19494       bidirectional_9[0][0]
# __________________________________________________________________________________________________
# label_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# input_length (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# ctc (Lambda)                    (None, 1)            0           label[0][0]
#                                                                  output[0][0]
#                                                                  label_length[0][0]
#                                                                  input_length[0][0]
# ==================================================================================================
# Total params: 7,838,694
# Trainable params: 7,836,646
# Non-trainable params: 2,048
# __________________________________________________________________________________________________

# %%
train_set = MJDatasetSequence(TRAIN_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS, is_train=True)
val_set = MJDatasetSequence(VALID_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS)
sgd = tf.keras.optimizers.Adadelta(lr=0.1, clipnorm=5)
model.compile(loss={'ctc': lambda y_true, y_pred: y_pred}, optimizer=sgd)
ckp = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_path, monitor='val_loss',
    verbose=1, save_best_only=True
)
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=0, mode='min'
)
model.fit(train_set,
        steps_per_epoch=len(val_set),
        epochs=100,
        validation_data=val_set,
        validation_steps=len(val_set),
        callbacks=[ckp])
# Out:
# cr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 155ms/step - loss: 7.7298 - val_loss: 8.4053
# Epoch 23/100
# 63/63 [==============================] - ETA: 0s - loss: 7.5491
# Epoch 00023: val_loss improved from 8.40533 to 8.26299, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 7.5491 - val_loss: 8.2630
# Epoch 24/100
# 63/63 [==============================] - ETA: 0s - loss: 7.1216
# Epoch 00024: val_loss improved from 8.26299 to 7.35885, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 155ms/step - loss: 7.1216 - val_loss: 7.3588
# Epoch 25/100
# 63/63 [==============================] - ETA: 0s - loss: 6.8309
# Epoch 00025: val_loss improved from 7.35885 to 7.07053, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 6.8309 - val_loss: 7.0705
# Epoch 26/100
# 63/63 [==============================] - ETA: 0s - loss: 6.6710
# Epoch 00026: val_loss improved from 7.07053 to 6.92478, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 158ms/step - loss: 6.6710 - val_loss: 6.9248
# Epoch 27/100
# 63/63 [==============================] - ETA: 0s - loss: 6.3981
# Epoch 00027: val_loss improved from 6.92478 to 6.73795, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 6.3981 - val_loss: 6.7380
# Epoch 28/100
# 63/63 [==============================] - ETA: 0s - loss: 6.0940
# Epoch 00028: val_loss did not improve from 6.73795
# 63/63 [==============================] - 10s 153ms/step - loss: 6.0940 - val_loss: 6.7979
# Epoch 29/100
# 63/63 [==============================] - ETA: 0s - loss: 6.1417
# Epoch 00029: val_loss improved from 6.73795 to 6.31312, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 6.1417 - val_loss: 6.3131
# Epoch 30/100
# 63/63 [==============================] - ETA: 0s - loss: 5.7491
# Epoch 00030: val_loss improved from 6.31312 to 6.07828, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 5.7491 - val_loss: 6.0783
# Epoch 31/100
# 63/63 [==============================] - ETA: 0s - loss: 5.8021
# Epoch 00031: val_loss improved from 6.07828 to 5.94926, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 5.8021 - val_loss: 5.9493
# Epoch 32/100
# 63/63 [==============================] - ETA: 0s - loss: 5.7216
# Epoch 00032: val_loss did not improve from 5.94926
# 63/63 [==============================] - 10s 153ms/step - loss: 5.7216 - val_loss: 6.0242
# Epoch 33/100
# 63/63 [==============================] - ETA: 0s - loss: 5.6789
# Epoch 00033: val_loss improved from 5.94926 to 5.68624, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 5.6789 - val_loss: 5.6862
# Epoch 34/100
# 63/63 [==============================] - ETA: 0s - loss: 5.4674
# Epoch 00034: val_loss did not improve from 5.68624
# 63/63 [==============================] - 10s 153ms/step - loss: 5.4674 - val_loss: 5.7019
# Epoch 35/100
# 63/63 [==============================] - ETA: 0s - loss: 5.1438
# Epoch 00035: val_loss did not improve from 5.68624
# 63/63 [==============================] - 10s 153ms/step - loss: 5.1438 - val_loss: 5.7520
# Epoch 36/100
# 63/63 [==============================] - ETA: 0s - loss: 5.2189
# Epoch 00036: val_loss improved from 5.68624 to 5.47291, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 159ms/step - loss: 5.2189 - val_loss: 5.4729
# Epoch 37/100
# 63/63 [==============================] - ETA: 0s - loss: 5.0614
# Epoch 00037: val_loss did not improve from 5.47291
# 63/63 [==============================] - 10s 153ms/step - loss: 5.0614 - val_loss: 5.6151
# Epoch 38/100
# 63/63 [==============================] - ETA: 0s - loss: 5.0174
# Epoch 00038: val_loss improved from 5.47291 to 5.45175, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 5.0174 - val_loss: 5.4518
# Epoch 39/100
# 63/63 [==============================] - ETA: 0s - loss: 4.9723
# Epoch 00039: val_loss improved from 5.45175 to 5.10923, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 4.9723 - val_loss: 5.1092
# Epoch 40/100
# 63/63 [==============================] - ETA: 0s - loss: 4.8949
# Epoch 00040: val_loss improved from 5.10923 to 5.10211, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 4.8949 - val_loss: 5.1021
# Epoch 41/100
# 63/63 [==============================] - ETA: 0s - loss: 4.8157
# Epoch 00041: val_loss improved from 5.10211 to 5.04268, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 4.8157 - val_loss: 5.0427
# Epoch 42/100
# 63/63 [==============================] - ETA: 0s - loss: 4.6257
# Epoch 00042: val_loss improved from 5.04268 to 4.85663, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 4.6257 - val_loss: 4.8566
# Epoch 43/100
# 63/63 [==============================] - ETA: 0s - loss: 4.5799
# Epoch 00043: val_loss did not improve from 4.85663
# 63/63 [==============================] - 10s 153ms/step - loss: 4.5799 - val_loss: 4.9052
# Epoch 44/100
# 63/63 [==============================] - ETA: 0s - loss: 4.5463
# Epoch 00044: val_loss improved from 4.85663 to 4.84089, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 155ms/step - loss: 4.5463 - val_loss: 4.8409
# Epoch 45/100
# 63/63 [==============================] - ETA: 0s - loss: 4.4272
# Epoch 00045: val_loss did not improve from 4.84089
# 63/63 [==============================] - 10s 154ms/step - loss: 4.4272 - val_loss: 4.9072
# Epoch 46/100
# 63/63 [==============================] - ETA: 0s - loss: 4.4285
# Epoch 00046: val_loss improved from 4.84089 to 4.54996, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 159ms/step - loss: 4.4285 - val_loss: 4.5500
# Epoch 47/100
# 63/63 [==============================] - ETA: 0s - loss: 4.3364
# Epoch 00047: val_loss did not improve from 4.54996
# 63/63 [==============================] - 10s 153ms/step - loss: 4.3364 - val_loss: 4.6338
# Epoch 48/100
# 63/63 [==============================] - ETA: 0s - loss: 4.1848
# Epoch 00048: val_loss improved from 4.54996 to 4.45231, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 4.1848 - val_loss: 4.4523
# Epoch 49/100
# 63/63 [==============================] - ETA: 0s - loss: 4.3771
# Epoch 00049: val_loss improved from 4.45231 to 4.35903, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 4.3771 - val_loss: 4.3590
# Epoch 50/100
# 63/63 [==============================] - ETA: 0s - loss: 4.2345
# Epoch 00050: val_loss improved from 4.35903 to 4.31107, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 4.2345 - val_loss: 4.3111
# Epoch 51/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0834
# Epoch 00051: val_loss did not improve from 4.31107
# 63/63 [==============================] - 10s 154ms/step - loss: 4.0834 - val_loss: 4.5369
# Epoch 52/100
# 63/63 [==============================] - ETA: 0s - loss: 4.1073
# Epoch 00052: val_loss did not improve from 4.31107
# 63/63 [==============================] - 10s 152ms/step - loss: 4.1073 - val_loss: 4.3260
# Epoch 53/100
# 63/63 [==============================] - ETA: 0s - loss: 3.9050
# Epoch 00053: val_loss did not improve from 4.31107
# 63/63 [==============================] - 10s 152ms/step - loss: 3.9050 - val_loss: 4.3967
# Epoch 54/100
# 63/63 [==============================] - ETA: 0s - loss: 3.9399
# Epoch 00054: val_loss improved from 4.31107 to 4.16128, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 3.9399 - val_loss: 4.1613
# Epoch 55/100
# 63/63 [==============================] - ETA: 0s - loss: 3.8778
# Epoch 00055: val_loss did not improve from 4.16128
# 63/63 [==============================] - 10s 153ms/step - loss: 3.8778 - val_loss: 4.2735
# Epoch 56/100
# 63/63 [==============================] - ETA: 0s - loss: 4.0108
# Epoch 00056: val_loss did not improve from 4.16128
# 63/63 [==============================] - 10s 153ms/step - loss: 4.0108 - val_loss: 4.1621
# Epoch 57/100
# 63/63 [==============================] - ETA: 0s - loss: 3.8519
# Epoch 00057: val_loss did not improve from 4.16128
# 63/63 [==============================] - 10s 153ms/step - loss: 3.8519 - val_loss: 4.2416
# Epoch 58/100
# 63/63 [==============================] - ETA: 0s - loss: 3.8155
# Epoch 00058: val_loss improved from 4.16128 to 3.93729, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 3.8155 - val_loss: 3.9373
# Epoch 59/100
# 63/63 [==============================] - ETA: 0s - loss: 3.8100
# Epoch 00059: val_loss did not improve from 3.93729
# 63/63 [==============================] - 10s 153ms/step - loss: 3.8100 - val_loss: 4.0491
# Epoch 60/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6377
# Epoch 00060: val_loss did not improve from 3.93729
# 63/63 [==============================] - 10s 154ms/step - loss: 3.6377 - val_loss: 4.0262
# Epoch 61/100
# 63/63 [==============================] - ETA: 0s - loss: 3.9089
# Epoch 00061: val_loss did not improve from 3.93729
# 63/63 [==============================] - 10s 153ms/step - loss: 3.9089 - val_loss: 4.2695
# Epoch 62/100
# 63/63 [==============================] - ETA: 0s - loss: 3.6263
# Epoch 00062: val_loss did not improve from 3.93729
# 63/63 [==============================] - 10s 153ms/step - loss: 3.6263 - val_loss: 3.9561
# Epoch 63/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5688
# Epoch 00063: val_loss improved from 3.93729 to 3.69358, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 3.5688 - val_loss: 3.6936
# Epoch 64/100
# 63/63 [==============================] - ETA: 0s - loss: 3.7914
# Epoch 00064: val_loss did not improve from 3.69358
# 63/63 [==============================] - 10s 153ms/step - loss: 3.7914 - val_loss: 3.7504
# Epoch 65/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5750
# Epoch 00065: val_loss improved from 3.69358 to 3.63924, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 3.5750 - val_loss: 3.6392
# Epoch 66/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5112
# Epoch 00066: val_loss did not improve from 3.63924
# 63/63 [==============================] - 10s 154ms/step - loss: 3.5112 - val_loss: 3.7569
# Epoch 67/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4015
# Epoch 00067: val_loss did not improve from 3.63924
# 63/63 [==============================] - 10s 152ms/step - loss: 3.4015 - val_loss: 3.6512
# Epoch 68/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4384
# Epoch 00068: val_loss improved from 3.63924 to 3.55718, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 3.4384 - val_loss: 3.5572
# Epoch 69/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3023
# Epoch 00069: val_loss did not improve from 3.55718
# 63/63 [==============================] - 10s 153ms/step - loss: 3.3023 - val_loss: 3.8117
# Epoch 70/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3953
# Epoch 00070: val_loss did not improve from 3.55718
# 63/63 [==============================] - 10s 153ms/step - loss: 3.3953 - val_loss: 3.6439
# Epoch 71/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4385
# Epoch 00071: val_loss did not improve from 3.55718
# 63/63 [==============================] - 10s 154ms/step - loss: 3.4385 - val_loss: 3.5884
# Epoch 72/100
# 63/63 [==============================] - ETA: 0s - loss: 3.5159
# Epoch 00072: val_loss improved from 3.55718 to 3.53256, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 3.5159 - val_loss: 3.5326
# Epoch 73/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4784
# Epoch 00073: val_loss improved from 3.53256 to 3.51545, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 3.4784 - val_loss: 3.5154
# Epoch 74/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2265
# Epoch 00074: val_loss improved from 3.51545 to 3.42789, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 3.2265 - val_loss: 3.4279
# Epoch 75/100
# 63/63 [==============================] - ETA: 0s - loss: 3.4226
# Epoch 00075: val_loss did not improve from 3.42789
# 63/63 [==============================] - 10s 153ms/step - loss: 3.4226 - val_loss: 3.5215
# Epoch 76/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3111
# Epoch 00076: val_loss improved from 3.42789 to 3.41502, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 3.3111 - val_loss: 3.4150
# Epoch 77/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3232
# Epoch 00077: val_loss improved from 3.41502 to 3.33958, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 3.3232 - val_loss: 3.3396
# Epoch 78/100
# 63/63 [==============================] - ETA: 0s - loss: 3.3063
# Epoch 00078: val_loss did not improve from 3.33958
# 63/63 [==============================] - 10s 152ms/step - loss: 3.3063 - val_loss: 3.3651
# Epoch 79/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1704
# Epoch 00079: val_loss did not improve from 3.33958
# 63/63 [==============================] - 10s 154ms/step - loss: 3.1704 - val_loss: 3.3955
# Epoch 80/100
# 63/63 [==============================] - ETA: 0s - loss: 3.2868
# Epoch 00080: val_loss improved from 3.33958 to 3.32135, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 156ms/step - loss: 3.2868 - val_loss: 3.3213
# Epoch 81/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1982
# Epoch 00081: val_loss did not improve from 3.32135
# 63/63 [==============================] - 10s 154ms/step - loss: 3.1982 - val_loss: 3.3539
# Epoch 82/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1611
# Epoch 00082: val_loss improved from 3.32135 to 3.26631, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 3.1611 - val_loss: 3.2663
# Epoch 83/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1502
# Epoch 00083: val_loss improved from 3.26631 to 3.22156, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 157ms/step - loss: 3.1502 - val_loss: 3.2216
# Epoch 84/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0767
# Epoch 00084: val_loss did not improve from 3.22156
# 63/63 [==============================] - 10s 154ms/step - loss: 3.0767 - val_loss: 3.2246
# Epoch 85/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0435
# Epoch 00085: val_loss did not improve from 3.22156
# 63/63 [==============================] - 11s 172ms/step - loss: 3.0435 - val_loss: 3.3075
# Epoch 86/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1125
# Epoch 00086: val_loss improved from 3.22156 to 3.19501, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 159ms/step - loss: 3.1125 - val_loss: 3.1950
# Epoch 87/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0142
# Epoch 00087: val_loss did not improve from 3.19501
# 63/63 [==============================] - 10s 155ms/step - loss: 3.0142 - val_loss: 3.2146
# Epoch 88/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0820
# Epoch 00088: val_loss improved from 3.19501 to 3.16088, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 158ms/step - loss: 3.0820 - val_loss: 3.1609
# Epoch 89/100
# 63/63 [==============================] - ETA: 0s - loss: 3.1657
# Epoch 00089: val_loss did not improve from 3.16088
# 63/63 [==============================] - 10s 155ms/step - loss: 3.1657 - val_loss: 3.2019
# Epoch 90/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9600
# Epoch 00090: val_loss improved from 3.16088 to 3.12838, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 160ms/step - loss: 2.9600 - val_loss: 3.1284
# Epoch 91/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0334
# Epoch 00091: val_loss did not improve from 3.12838
# 63/63 [==============================] - 10s 155ms/step - loss: 3.0334 - val_loss: 3.2101
# Epoch 92/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9038
# Epoch 00092: val_loss did not improve from 3.12838
# 63/63 [==============================] - 10s 155ms/step - loss: 2.9038 - val_loss: 3.1444
# Epoch 93/100
# 63/63 [==============================] - ETA: 0s - loss: 3.0088
# Epoch 00093: val_loss improved from 3.12838 to 3.09836, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 158ms/step - loss: 3.0088 - val_loss: 3.0984
# Epoch 94/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9868
# Epoch 00094: val_loss did not improve from 3.09836
# 63/63 [==============================] - 10s 154ms/step - loss: 2.9868 - val_loss: 3.1406
# Epoch 95/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9641
# Epoch 00095: val_loss improved from 3.09836 to 3.01117, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 159ms/step - loss: 2.9641 - val_loss: 3.0112
# Epoch 96/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9933
# Epoch 00096: val_loss did not improve from 3.01117
# 63/63 [==============================] - 10s 155ms/step - loss: 2.9933 - val_loss: 3.2475
# Epoch 97/100
# 63/63 [==============================] - ETA: 0s - loss: 2.9410
# Epoch 00097: val_loss did not improve from 3.01117
# 63/63 [==============================] - 10s 155ms/step - loss: 2.9410 - val_loss: 3.0160
# Epoch 98/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8944
# Epoch 00098: val_loss improved from 3.01117 to 3.00506, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 158ms/step - loss: 2.8944 - val_loss: 3.0051
# Epoch 99/100
# 63/63 [==============================] - ETA: 0s - loss: 2.7986
# Epoch 00099: val_loss did not improve from 3.00506
# 63/63 [==============================] - 10s 154ms/step - loss: 2.7986 - val_loss: 3.0364
# Epoch 100/100
# 63/63 [==============================] - ETA: 0s - loss: 2.8260
# Epoch 00100: val_loss improved from 3.00506 to 2.90640, saving model to /home/aiffel-dj26/aiffel/ocr/model_checkpoint.hdf5
# 63/63 [==============================] - 10s 159ms/step - loss: 2.8260 - val_loss: 2.9064

# %%
from IPython.display import display
# from keras.models import load_model
test_set = MJDatasetSequence(TEST_DATA_PATH, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS)

# model, y_func = build_crnn_model()
# model.load_weight(checkpoint_path)
# model = load_model(checkpoint_path)
input_data = model.get_layer('input_image').output
y_pred = model.get_layer('output').output
model_pred = Model(inputs=input_data, outputs=y_pred)

def decode_predict_ctc(out, chars = TARGET_CHARACTERS, top_paths = 1):
    results = []
    beam_width = 5
    if beam_width < top_paths:
        beam_width = top_paths
    for i in range(top_paths):
        indexes = K.get_value(
            K.ctc_decode(
                out, input_length = np.ones(out.shape[0]) * out.shape[1],
                greedy =False , beam_width = beam_width, top_paths = top_paths
            )[0][i]
        )[0]
        text = ""
        for index in indexes:
            text += chars[index]
        results.append(text)
    return results

def check_inference(model, dataset, index = 5):
    for i in range(index):
        inputs, outputs = dataset[i]
        img = dataset[i][0]['input_image'][0:1,:,:,:]
        output = model_pred.predict(img)
        result = decode_predict_ctc(output, chars="-"+TARGET_CHARACTERS)[0].replace('-','')
        print("Result: \t", result)
        display(Image.fromarray(img[0].transpose(1,0,2).astype(np.uint8)))

check_inference(model, test_set, index=5)
# Out:
# Result: 	 SLINKING
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7FD7A2F794D0>
# Result: 	 ALEPPO
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7FD7A2F794D0>
# Result: 	 RWENDA
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7FD83C315990>
# Result: 	 NATHANS
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7FD7A2F794D0>
# Result: 	 HALLEO
# <PIL.Image.Image image mode=RGB size=100x32 at 0x7FD83C266310>

# %%
def detect_text(img_path,label_converter= label_converter,model=model,TARGET_CHARACTERS=TARGET_CHARACTERS):
    dataset = MJDatasetSequence(img_path, label_converter, batch_size=BATCH_SIZE, character=TARGET_CHARACTERS)
    check_inference(model,dataset)
    cropped_imgs = []
    for text_result in ocr_result:
        img_draw.polygon(text_result, outline='red')
        x_min = text_result[:,0].min() - 5
        x_max = text_result[:,0].max() + 5
        y_min = text_result[:,1].min() - 5
        y_max = text_result[:,1].max() + 5
        word_box = [x_min, y_min, x_max, y_max]
        cropped_imgs.append(img_pil.crop(word_box))


    return result_img, cropped_imgs

# %%
import keras_ocr
from keras_ocr.detection import Detector
from keras_ocr.recognition import Recognizer
def detect_text(img_path):
    pipeline = keras_ocr.pipeline.Pipeline()
    # recog = Recognizer()
    images = keras_ocr.tools.read(img_path)
    predictions = pipeline.recognize([img_path])
    
    result_img = keras_ocr.tools.drawAnnotations(image=images, predictions=predictions[0])

    cropped_imgs = []
    revised_boxes = []
    for _, box in predictions[0]:
        revised_boxes.append(box)
    boxes = revised_boxes
    cropped_imgs = []
    revised_boxes = []
    for _, box in predictions[0]:
        revised_boxes.append(box)
    boxes = revised_boxes

    crop_box =[]
    for box in boxes:
        cropped_imgs.append(keras_ocr.tools.warpBox(image=images, box=box))


    return result_img, cropped_imgs

# %%
def recognize_img(pil_img, input_img_size=(100,32)):
    img90 = cv2.rotate(pil_img, cv2.ROTATE_90_COUNTERCLOCKWISE)
    img_flip = cv2.flip(img90, 0)
    pil_img = cv2.resize(img_flip, (32, 100), interpolation = cv2.INTER_CUBIC)
    img = pil_img.reshape(1, 100, 32, 3)
    output = model_pred.predict(img)
    result = decode_predict_ctc(output, chars="-"+TARGET_CHARACTERS)[0].replace('-','')
    print("Result: \t", result)
    display(Image.fromarray(img[0].transpose(1,0,2).astype(np.uint8)))

# %%
path = os.path.join(os.getenv('HOME'),'aiffel/ocr/')
# path = os.getenv('HOME') +'aiffel/ocr/'
SAMPLE_IMG_PATH = path+'sample.jpg'

# %%
img_pil, cropped_img = detect_text(SAMPLE_IMG_PATH)
display(img_pil)
# Out:
# Looking for /home/aiffel-dj26/.keras-ocr/craft_mlt_25k.h5
# Looking for /home/aiffel-dj26/.keras-ocr/crnn_kurapan.h5
# <AxesSubplot:>

# %% [markdown]
# # 고찰
# OCR을 하며 버전오류로 몇번의 가상환경을 만들었다 지웠는지 모르겠다
# 현재 모델 웨이트가 안불러와져 다시 학습시키고 확인하였다
# keras_ocr 같은 경우 영어의 영역을 잘 알아보지만 아랍어는 잘 못보는 것을 알 수 있다.
